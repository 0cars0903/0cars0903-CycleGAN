# %%
#라이브러리 호출
import cv2
import os

print(cv2.__version__)
# Out:
# 4.7.0

# %%
# %cd C:/Users/piai/Desktop/work/CycleGAN_project/video
filepath = './video1_trim.mp4'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)
# Out:
# C:\Users\piai\Desktop\work\CycleGAN_project\video

# %%
#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
# Out:
# length : 18494
# width : 1280
# height : 720
# fps : 24.0

# %%
#프레임을 저장할 디렉토리를 생성
try:
    if not os.path.exists(filepath[:-4]):
        os.makedirs(filepath[:-4])
except OSError:
    print ('Error: Creating directory. ' +  filepath[:-4])

# %%
# fps 값을 사용하여 1초마다 프레임 저장
count = 0

while(video.isOpened()):
    ret, image = video.read()
    if(int(video.get(1)) % fps == 0): #앞서 불러온 fps 값을 사용하여 1초마다 추출
        cv2.imwrite(filepath[:-4] + "/frame%d.jpg" % count, image)
        print('Saved frame number :', str(int(video.get(1))))
        count += 1
        
video.release()
# Out:
# Saved frame number : 24
# Saved frame number : 48
# Saved frame number : 72
# Saved frame number : 96
# Saved frame number : 120
# Saved frame number : 144
# Saved frame number : 168
# Saved frame number : 192
# Saved frame number : 216
# Saved frame number : 240
# Saved frame number : 264
# Saved frame number : 288
# Saved frame number : 312
# Saved frame number : 336
# Saved frame number : 360
# Saved frame number : 384
# Saved frame number : 408
# Saved frame number : 432
# Saved frame number : 456
# Saved frame number : 480
# Saved frame number : 504
# Saved frame number : 528
# Saved frame number : 552
# Saved frame number : 576
# Saved frame number : 600
# Saved frame number : 624
# Saved frame number : 648
# Saved frame number : 672
# Saved frame number : 696
# Saved frame number : 720
# Saved frame number : 744
# Saved frame number : 768
# Saved frame number : 792
# Saved frame number : 816
# Saved frame number : 840
# Saved frame number : 864
# Saved frame number : 888
# Saved frame number : 912
# Saved frame number : 936
# Saved frame number : 960
# Saved frame number : 984
# Saved frame number : 1008
# Saved frame number : 1032
# Saved frame number : 1056
# Saved frame number : 1080
# Saved frame number : 1104
# Saved frame number : 1128
# Saved frame number : 1152
# Saved frame number : 1176
# Saved frame number : 1200
# Saved frame number : 1224
# Saved frame number : 1248
# Saved frame number : 1272
# Saved frame number : 1296
# Saved frame number : 1320
# Saved frame number : 1344
# Saved frame number : 1368
# Saved frame number : 1392
# Saved frame number : 1416
# Saved frame number : 1440
# Saved frame number : 1464
# Saved frame number : 1488
# Saved frame number : 1512
# Saved frame number : 1536
# Saved frame number : 1560
# Saved frame number : 1584
# Saved frame number : 1608
# Saved frame number : 1632
# Saved frame number : 1656
# Saved frame number : 1680
# Saved frame number : 1704
# Saved frame number : 1728
# Saved frame number : 1752
# Saved frame number : 1776
# Saved frame number : 1800
# Saved frame number : 1824
# Saved frame number : 1848
# Saved frame number : 1872
# Saved frame number : 1896
# Saved frame number : 1920
# Saved frame number : 1944
# Saved frame number : 1968
# Saved frame number : 1992
# Saved frame number : 2016
# Saved frame number : 2040
# Saved frame number : 2064
# Saved frame number : 2088
# Saved frame number : 2112
# Saved frame number : 2136
# Saved frame number : 2160
# Saved frame number : 2184
# Saved frame number : 2208
# Saved frame number : 2232
# Saved frame number : 2256
# Saved frame number : 2280
# Saved frame number : 2304
# Saved frame number : 2328
# Saved frame number : 2352
# Saved frame number : 2376
# Saved frame number : 2400
# Saved frame number : 2424
# Saved frame number : 2448
# Saved frame number : 2472
# Saved frame number : 2496
# Saved frame number : 2520
# Saved frame number : 2544
# Saved frame number : 2568
# Saved frame number : 2592
# Saved frame number : 2616
# Saved frame number : 2640
# Saved frame number : 2664
# Saved frame number : 2688
# Saved frame number : 2712
# Saved frame number : 2736
# Saved frame number : 2760
# Saved frame number : 2784
# Saved frame number : 2808
# Saved frame number : 2832
# Saved frame number : 2856
# Saved frame number : 2880
# Saved frame number : 2904
# Saved frame number : 2928
# Saved frame number : 2952
# Saved frame number : 2976
# Saved frame number : 3000
# Saved frame number : 3024
# Saved frame number : 3048
# Saved frame number : 3072
# Saved frame number : 3096
# Saved frame number : 3120
# Saved frame number : 3144
# Saved frame number : 3168
# Saved frame number : 3192
# Saved frame number : 3216
# Saved frame number : 3240
# Saved frame number : 3264
# Saved frame number : 3288
# Saved frame number : 3312
# Saved frame number : 3336
# Saved frame number : 3360
# Saved frame number : 3384
# Saved frame number : 3408
# Saved frame number : 3432
# Saved frame number : 3456
# Saved frame number : 3480
# Saved frame number : 3504
# Saved frame number : 3528
# Saved frame number : 3552
# Saved frame number : 3576
# Saved frame number : 3600
# Saved frame number : 3624
# Saved frame number : 3648
# Saved frame number : 3672
# Saved frame number : 3696
# Saved frame number : 3720
# Saved frame number : 3744
# Saved frame number : 3768
# Saved frame number : 3792
# Saved frame number : 3816
# Saved frame number : 3840
# Saved frame number : 3864
# Saved frame number : 3888
# Saved frame number : 3912
# Saved frame number : 3936
# Saved frame number : 3960
# Saved frame number : 3984
# Saved frame number : 4008
# Saved frame number : 4032
# Saved frame number : 4056
# Saved frame number : 4080
# Saved frame number : 4104
# Saved frame number : 4128
# Saved frame number : 4152
# Saved frame number : 4176
# Saved frame number : 4200
# Saved frame number : 4224
# Saved frame number : 4248
# Saved frame number : 4272
# Saved frame number : 4296
# Saved frame number : 4320
# Saved frame number : 4344
# Saved frame number : 4368
# Saved frame number : 4392
# Saved frame number : 4416
# Saved frame number : 4440
# Saved frame number : 4464
# Saved frame number : 4488
# Saved frame number : 4512
# Saved frame number : 4536
# Saved frame number : 4560
# Saved frame number : 4584
# Saved frame number : 4608
# Saved frame number : 4632
# Saved frame number : 4656
# Saved frame number : 4680
# Saved frame number : 4704
# Saved frame number : 4728
# Saved frame number : 4752
# Saved frame number : 4776
# Saved frame number : 4800
# Saved frame number : 4824
# Saved frame number : 4848
# Saved frame number : 4872
# Saved frame number : 4896
# Saved frame number : 4920
# Saved frame number : 4944
# Saved frame number : 4968
# Saved frame number : 4992
# Saved frame number : 5016
# Saved frame number : 5040
# Saved frame number : 5064
# Saved frame number : 5088
# Saved frame number : 5112
# Saved frame number : 5136
# Saved frame number : 5160
# Saved frame number : 5184
# Saved frame number : 5208
# Saved frame number : 5232
# Saved frame number : 5256
# Saved frame number : 5280
# Saved frame number : 5304
# Saved frame number : 5328
# Saved frame number : 5352
# Saved frame number : 5376
# Saved frame number : 5400
# Saved frame number : 5424
# Saved frame number : 5448
# Saved frame number : 5472
# Saved frame number : 5496
# Saved frame number : 5520
# Saved frame number : 5544
# Saved frame number : 5568
# Saved frame number : 5592
# Saved frame number : 5616
# Saved frame number : 5640
# Saved frame number : 5664
# Saved frame number : 5688
# Saved frame number : 5712
# Saved frame number : 5736
# Saved frame number : 5760
# Saved frame number : 5784
# Saved frame number : 5808
# Saved frame number : 5832
# Saved frame number : 5856
# Saved frame number : 5880
# Saved frame number : 5904
# Saved frame number : 5928
# Saved frame number : 5952
# Saved frame number : 5976
# Saved frame number : 6000
# Saved frame number : 6024
# Saved frame number : 6048
# Saved frame number : 6072
# Saved frame number : 6096
# Saved frame number : 6120
# Saved frame number : 6144
# Saved frame number : 6168
# Saved frame number : 6192
# Saved frame number : 6216
# Saved frame number : 6240
# Saved frame number : 6264
# Saved frame number : 6288
# Saved frame number : 6312
# Saved frame number : 6336
# Saved frame number : 6360
# Saved frame number : 6384
# Saved frame number : 6408
# Saved frame number : 6432
# Saved frame number : 6456
# Saved frame number : 6480
# Saved frame number : 6504
# Saved frame number : 6528
# Saved frame number : 6552
# Saved frame number : 6576
# Saved frame number : 6600
# Saved frame number : 6624
# Saved frame number : 6648
# Saved frame number : 6672
# Saved frame number : 6696
# Saved frame number : 6720
# Saved frame number : 6744
# Saved frame number : 6768
# Saved frame number : 6792
# Saved frame number : 6816
# Saved frame number : 6840
# Saved frame number : 6864
# Saved frame number : 6888
# Saved frame number : 6912
# Saved frame number : 6936
# Saved frame number : 6960
# Saved frame number : 6984
# Saved frame number : 7008
# Saved frame number : 7032
# Saved frame number : 7056
# Saved frame number : 7080
# Saved frame number : 7104
# Saved frame number : 7128
# Saved frame number : 7152
# Saved frame number : 7176
# Saved frame number : 7200
# Saved frame number : 7224
# Saved frame number : 7248
# Saved frame number : 7272
# Saved frame number : 7296
# Saved frame number : 7320
# Saved frame number : 7344
# Saved frame number : 7368
# Saved frame number : 7392
# Saved frame number : 7416
# Saved frame number : 7440
# Saved frame number : 7464
# Saved frame number : 7488
# Saved frame number : 7512
# Saved frame number : 7536
# Saved frame number : 7560
# Saved frame number : 7584
# Saved frame number : 7608
# Saved frame number : 7632
# Saved frame number : 7656
# Saved frame number : 7680
# Saved frame number : 7704
# Saved frame number : 7728
# Saved frame number : 7752
# Saved frame number : 7776
# Saved frame number : 7800
# Saved frame number : 7824
# Saved frame number : 7848
# Saved frame number : 7872
# Saved frame number : 7896
# Saved frame number : 7920
# Saved frame number : 7944
# Saved frame number : 7968
# Saved frame number : 7992
# Saved frame number : 8016
# Saved frame number : 8040
# Saved frame number : 8064
# Saved frame number : 8088
# Saved frame number : 8112
# Saved frame number : 8136
# Saved frame number : 8160
# Saved frame number : 8184
# Saved frame number : 8208
# Saved frame number : 8232
# Saved frame number : 8256
# Saved frame number : 8280
# Saved frame number : 8304
# Saved frame number : 8328
# Saved frame number : 8352
# Saved frame number : 8376
# Saved frame number : 8400
# Saved frame number : 8424
# Saved frame number : 8448
# Saved frame number : 8472
# Saved frame number : 8496
# Saved frame number : 8520
# Saved frame number : 8544
# Saved frame number : 8568
# Saved frame number : 8592
# Saved frame number : 8616
# Saved frame number : 8640
# Saved frame number : 8664
# Saved frame number : 8688
# Saved frame number : 8712
# Saved frame number : 8736
# Saved frame number : 8760
# Saved frame number : 8784
# Saved frame number : 8808
# Saved frame number : 8832
# Saved frame number : 8856
# Saved frame number : 8880
# Saved frame number : 8904
# Saved frame number : 8928
# Saved frame number : 8952
# Saved frame number : 8976
# Saved frame number : 9000
# Saved frame number : 9024
# Saved frame number : 9048
# Saved frame number : 9072
# Saved frame number : 9096
# Saved frame number : 9120
# Saved frame number : 9144
# Saved frame number : 9168
# Saved frame number : 9192
# Saved frame number : 9216
# Saved frame number : 9240
# Saved frame number : 9264
# Saved frame number : 9288
# Saved frame number : 9312
# Saved frame number : 9336
# Saved frame number : 9360
# Saved frame number : 9384
# Saved frame number : 9408
# Saved frame number : 9432
# Saved frame number : 9456
# Saved frame number : 9480
# Saved frame number : 9504
# Saved frame number : 9528
# Saved frame number : 9552
# Saved frame number : 9576
# Saved frame number : 9600
# Saved frame number : 9624
# Saved frame number : 9648
# Saved frame number : 9672
# Saved frame number : 9696
# Saved frame number : 9720
# Saved frame number : 9744
# Saved frame number : 9768
# Saved frame number : 9792
# Saved frame number : 9816
# Saved frame number : 9840
# Saved frame number : 9864
# Saved frame number : 9888
# Saved frame number : 9912
# Saved frame number : 9936
# Saved frame number : 9960
# Saved frame number : 9984
# Saved frame number : 10008
# Saved frame number : 10032
# Saved frame number : 10056
# Saved frame number : 10080
# Saved frame number : 10104
# Saved frame number : 10128
# Saved frame number : 10152
# Saved frame number : 10176
# Saved frame number : 10200
# Saved frame number : 10224
# Saved frame number : 10248
# Saved frame number : 10272
# Saved frame number : 10296
# Saved frame number : 10320
# Saved frame number : 10344
# Saved frame number : 10368
# Saved frame number : 10392
# Saved frame number : 10416
# Saved frame number : 10440
# Saved frame number : 10464
# Saved frame number : 10488
# Saved frame number : 10512
# Saved frame number : 10536
# Saved frame number : 10560
# Saved frame number : 10584
# Saved frame number : 10608
# Saved frame number : 10632
# Saved frame number : 10656
# Saved frame number : 10680
# Saved frame number : 10704
# Saved frame number : 10728
# Saved frame number : 10752
# Saved frame number : 10776
# Saved frame number : 10800
# Saved frame number : 10824
# Saved frame number : 10848
# Saved frame number : 10872
# Saved frame number : 10896
# Saved frame number : 10920
# Saved frame number : 10944
# Saved frame number : 10968
# Saved frame number : 10992
# Saved frame number : 11016
# Saved frame number : 11040
# Saved frame number : 11064
# Saved frame number : 11088
# Saved frame number : 11112
# Saved frame number : 11136
# Saved frame number : 11160
# Saved frame number : 11184
# Saved frame number : 11208
# Saved frame number : 11232
# Saved frame number : 11256
# Saved frame number : 11280
# Saved frame number : 11304
# Saved frame number : 11328
# Saved frame number : 11352
# Saved frame number : 11376
# Saved frame number : 11400
# Saved frame number : 11424
# Saved frame number : 11448
# Saved frame number : 11472
# Saved frame number : 11496
# Saved frame number : 11520
# Saved frame number : 11544
# Saved frame number : 11568
# Saved frame number : 11592
# Saved frame number : 11616
# Saved frame number : 11640
# Saved frame number : 11664
# Saved frame number : 11688
# Saved frame number : 11712
# Saved frame number : 11736
# Saved frame number : 11760
# Saved frame number : 11784
# Saved frame number : 11808
# Saved frame number : 11832
# Saved frame number : 11856
# Saved frame number : 11880
# Saved frame number : 11904
# Saved frame number : 11928
# Saved frame number : 11952
# Saved frame number : 11976
# Saved frame number : 12000
# Saved frame number : 12024
# Saved frame number : 12048
# Saved frame number : 12072
# Saved frame number : 12096
# Saved frame number : 12120
# Saved frame number : 12144
# Saved frame number : 12168
# Saved frame number : 12192
# Saved frame number : 12216
# Saved frame number : 12240
# Saved frame number : 12264
# Saved frame number : 12288
# Saved frame number : 12312
# Saved frame number : 12336
# Saved frame number : 12360
# Saved frame number : 12384
# Saved frame number : 12408
# Saved frame number : 12432
# Saved frame number : 12456
# Saved frame number : 12480
# Saved frame number : 12504
# Saved frame number : 12528
# Saved frame number : 12552
# Saved frame number : 12576
# Saved frame number : 12600
# Saved frame number : 12624
# Saved frame number : 12648
# Saved frame number : 12672
# Saved frame number : 12696
# Saved frame number : 12720
# Saved frame number : 12744
# Saved frame number : 12768
# Saved frame number : 12792
# Saved frame number : 12816
# Saved frame number : 12840
# Saved frame number : 12864
# Saved frame number : 12888
# Saved frame number : 12912
# Saved frame number : 12936
# Saved frame number : 12960
# Saved frame number : 12984
# Saved frame number : 13008
# Saved frame number : 13032
# Saved frame number : 13056
# Saved frame number : 13080
# Saved frame number : 13104
# Saved frame number : 13128
# Saved frame number : 13152
# Saved frame number : 13176
# Saved frame number : 13200
# Saved frame number : 13224
# Saved frame number : 13248
# Saved frame number : 13272
# Saved frame number : 13296
# Saved frame number : 13320
# Saved frame number : 13344
# Saved frame number : 13368
# Saved frame number : 13392
# Saved frame number : 13416
# Saved frame number : 13440
# Saved frame number : 13464
# Saved frame number : 13488
# Saved frame number : 13512
# Saved frame number : 13536
# Saved frame number : 13560
# Saved frame number : 13584
# Saved frame number : 13608
# Saved frame number : 13632
# Saved frame number : 13656
# Saved frame number : 13680
# Saved frame number : 13704
# Saved frame number : 13728
# Saved frame number : 13752
# Saved frame number : 13776
# Saved frame number : 13800
# Saved frame number : 13824
# Saved frame number : 13848
# Saved frame number : 13872
# Saved frame number : 13896
# Saved frame number : 13920
# Saved frame number : 13944
# Saved frame number : 13968
# Saved frame number : 13992
# Saved frame number : 14016
# Saved frame number : 14040
# Saved frame number : 14064
# Saved frame number : 14088
# Saved frame number : 14112
# Saved frame number : 14136
# Saved frame number : 14160
# Saved frame number : 14184
# Saved frame number : 14208
# Saved frame number : 14232
# Saved frame number : 14256
# Saved frame number : 14280
# Saved frame number : 14304
# Saved frame number : 14328
# Saved frame number : 14352
# Saved frame number : 14376
# Saved frame number : 14400
# Saved frame number : 14424
# Saved frame number : 14448
# Saved frame number : 14472
# Saved frame number : 14496
# Saved frame number : 14520
# Saved frame number : 14544
# Saved frame number : 14568
# Saved frame number : 14592
# Saved frame number : 14616
# Saved frame number : 14640
# Saved frame number : 14664
# Saved frame number : 14688
# Saved frame number : 14712
# Saved frame number : 14736
# Saved frame number : 14760
# Saved frame number : 14784
# Saved frame number : 14808
# Saved frame number : 14832
# Saved frame number : 14856
# Saved frame number : 14880
# Saved frame number : 14904
# Saved frame number : 14928
# Saved frame number : 14952
# Saved frame number : 14976
# Saved frame number : 15000
# Saved frame number : 15024
# Saved frame number : 15048
# Saved frame number : 15072
# Saved frame number : 15096
# Saved frame number : 15120
# Saved frame number : 15144
# Saved frame number : 15168
# Saved frame number : 15192
# Saved frame number : 15216
# Saved frame number : 15240
# Saved frame number : 15264
# Saved frame number : 15288
# Saved frame number : 15312
# Saved frame number : 15336
# Saved frame number : 15360
# Saved frame number : 15384
# Saved frame number : 15408
# Saved frame number : 15432
# Saved frame number : 15456
# Saved frame number : 15480
# Saved frame number : 15504
# Saved frame number : 15528
# Saved frame number : 15552
# Saved frame number : 15576
# Saved frame number : 15600
# Saved frame number : 15624
# Saved frame number : 15648
# Saved frame number : 15672
# Saved frame number : 15696
# Saved frame number : 15720
# Saved frame number : 15744
# Saved frame number : 15768
# Saved frame number : 15792
# Saved frame number : 15816
# Saved frame number : 15840
# Saved frame number : 15864
# Saved frame number : 15888
# Saved frame number : 15912
# Saved frame number : 15936
# Saved frame number : 15960
# Saved frame number : 15984
# Saved frame number : 16008
# Saved frame number : 16032
# Saved frame number : 16056
# Saved frame number : 16080
# Saved frame number : 16104
# Saved frame number : 16128
# Saved frame number : 16152
# Saved frame number : 16176
# Saved frame number : 16200
# Saved frame number : 16224
# Saved frame number : 16248
# Saved frame number : 16272
# Saved frame number : 16296
# Saved frame number : 16320
# Saved frame number : 16344
# Saved frame number : 16368
# Saved frame number : 16392
# Saved frame number : 16416
# Saved frame number : 16440
# Saved frame number : 16464
# Saved frame number : 16488
# Saved frame number : 16512
# Saved frame number : 16536
# Saved frame number : 16560
# Saved frame number : 16584
# Saved frame number : 16608
# Saved frame number : 16632
# Saved frame number : 16656
# Saved frame number : 16680
# Saved frame number : 16704
# Saved frame number : 16728
# Saved frame number : 16752
# Saved frame number : 16776
# Saved frame number : 16800
# Saved frame number : 16824
# Saved frame number : 16848
# Saved frame number : 16872
# Saved frame number : 16896
# Saved frame number : 16920
# Saved frame number : 16944
# Saved frame number : 16968
# Saved frame number : 16992
# Saved frame number : 17016
# Saved frame number : 17040
# Saved frame number : 17064
# Saved frame number : 17088
# Saved frame number : 17112
# Saved frame number : 17136
# Saved frame number : 17160
# Saved frame number : 17184
# Saved frame number : 17208
# Saved frame number : 17232
# Saved frame number : 17256
# Saved frame number : 17280
# Saved frame number : 17304
# Saved frame number : 17328
# Saved frame number : 17352
# Saved frame number : 17376
# Saved frame number : 17400
# Saved frame number : 17424
# Saved frame number : 17448
# Saved frame number : 17472
# Saved frame number : 17496
# Saved frame number : 17520
# Saved frame number : 17544
# Saved frame number : 17568
# Saved frame number : 17592
# Saved frame number : 17616
# Saved frame number : 17640
# Saved frame number : 17664
# Saved frame number : 17688
# Saved frame number : 17712
# Saved frame number : 17736
# Saved frame number : 17760
# Saved frame number : 17784
# Saved frame number : 17808
# Saved frame number : 17832
# Saved frame number : 17856
# Saved frame number : 17880
# Saved frame number : 17904
# Saved frame number : 17928
# Saved frame number : 17952
# Saved frame number : 17976
# Saved frame number : 18000
# Saved frame number : 18024
# Saved frame number : 18048
# Saved frame number : 18072
# Saved frame number : 18096
# Saved frame number : 18120
# Saved frame number : 18144
# Saved frame number : 18168
# Saved frame number : 18192
# Saved frame number : 18216
# Saved frame number : 18240
# Saved frame number : 18264
# Saved frame number : 18288
# Saved frame number : 18312
# Saved frame number : 18336
# Saved frame number : 18360
# Saved frame number : 18384
# Saved frame number : 18408
# Saved frame number : 18432
# Saved frame number : 18456
# Saved frame number : 18480
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 count = 0
#       4 while(video.isOpened()):
# ----> 5     ret, image = video.read()
#       6     if(int(video.get(1)) % fps == 0): #앞서 불러온 fps 값을 사용하여 1초마다 추출
#       7         cv2.imwrite(filepath[:-4] + "/frame%d.jpg" % count, image)
#
# KeyboardInterrupt:
